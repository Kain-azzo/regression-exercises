# %%
import pandas as pd
import numpy as np
import env

import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from sklearn.model_selection import train_test_split
from scipy.stats import spearmanr
from wrangle import get_zillow,prep_zillow,split_data

warnings.filterwarnings('ignore')

# %%
def plot_categorical_and_continuous_vars(df):
    
    return df

# %%
zillow = (get_zillow)

# %%
preppedzillow = prep_zillow(zillow)
# Out:
# this file doesnt exist, read from sql, and export to csv

# %%
preppedzillow.head(5)
# Out:
#     bedrooms  bathrooms  area  taxvalue  yearbuilt  taxamount county
# 4          4        2.0  3633    296425       2005    6941.39     LA
# 6          3        4.0  1620    847770       2011   10244.94     LA
# 7          3        2.0  2077    646760       1926    7924.68     LA
# 11         0        0.0  1200      5328       1972      91.60     LA
# 14         0        0.0   171      6920       1973     255.17     LA

# %%
preppedzillow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2140235 entries, 4 to 2152862
# Data columns (total 7 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   bedrooms   int64
#  1   bathrooms  float64
#  2   area       int64
#  3   taxvalue   int64
#  4   yearbuilt  int64
#  5   taxamount  float64
#  6   county     object
# dtypes: float64(2), int64(4), object(1)
# memory usage: 130.6+ MB

# %%
train, validate, test = split_data(preppedzillow)

# %%
house_corr =train.drop(columns="county").corr(method="spearman")
sns.heatmap(house_corr)
plt.show()

# %%
sns.heatmap(house_corr, cmap='YlGnBu', annot=True, mask=np.triu(house_corr))
plt.show()

# %%
sns.pairplot(data=train.drop(columns="county"),corner=True);
plt.show()
